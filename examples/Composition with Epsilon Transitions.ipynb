# %% [markdown]
# # Composition with Epsilon Transitions

# %%
import pywrapfst as fst
syms = fst.SymbolTable()
syms.add_symbol('e')  # Epsilon (empty character)
syms.add_symbol('a')
syms.add_symbol('b')
syms.add_symbol('c')
# Out:
# 3

# %% [markdown]
# ### An example composition without epsilon transitions

# %%
fst1 = fst.Fst()
fst1.add_state()
fst1.set_start(0)
fst1.set_final(0)
fst1.add_state()
fst1.set_final(1)
fst1.add_arc(0,fst.Arc(1,3,0,1))
fst1.set_input_symbols(syms).set_output_symbols(syms)
# Out:
# <vector Fst at 0x15d22ffa810>

# %%
fst2 = fst.Fst()
fst2.add_state()
fst2.set_start(0)
fst2.set_final(0)
fst2.add_state()
fst2.set_final(1)
fst2.add_arc(0,fst.Arc(3,2,0,1))
fst2.set_input_symbols(syms).set_output_symbols(syms)
# Out:
# <vector Fst at 0x15d22ffa8f0>

# %%
fst.compose(fst1,fst2)
# Out:
# <vector Fst at 0x15d22fbadf8>

# %% [markdown]
# ### With epsilon transitions

# %%
fst1 = fst.Fst()
fst1.add_state()
fst1.set_start(0)
fst1.set_final(0)
fst1.add_state()
fst1.set_final(1)
fst1.add_arc(0,fst.Arc(1,0,0,1))
fst1.set_input_symbols(syms).set_output_symbols(syms)
# Out:
# <vector Fst at 0x15d22ffac38>

# %%
fst2 = fst.Fst()
fst2.add_state()
fst2.set_start(0)
fst2.set_final(0)
fst2.add_state()
fst2.set_final(1)
fst2.add_arc(0,fst.Arc(0,2,0,1))
fst2.set_input_symbols(syms).set_output_symbols(syms)
# Out:
# <vector Fst at 0x15d22ffad88>

# %%
fst.compose(fst1,fst2)
# Out:
# <vector Fst at 0x15d22fc1f48>
