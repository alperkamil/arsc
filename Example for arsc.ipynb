# %%
import arsc
MK,P,As,Aa = arsc.example()
MK
# Out:
# <vector Fst at 0x1edcf7c4570>

# %%
As
# Out:
# <vector Fst at 0x1edcf7c45e0>

# %%
Aa
# Out:
# <vector Fst at 0x1edcf7c46c0>

# %%
S, controllable = arsc.supervisor(MK,P,As,Aa)
S
# Out:
# <vector Fst at 0x1edd0201998>

# %%
controllable
# Out:
# True
